# %%
import os
import cv2
import numpy as np
from matplotlib import pyplot as plt
from skimage.feature import local_binary_pattern, hog, graycomatrix, graycoprops
from scipy import signal as sg
from tqdm import tqdm

# %% [markdown]
# ## Prepare dataset

# %% [markdown]
# ### feature extraction

# %%
def preprocess_image(image_path):
    image = cv2.imread(image_path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    gray = cv2.equalizeHist(gray)

    gray = cv2.medianBlur(gray, 3)

    edges = cv2.Canny(gray, 100, 200)
    edges = cv2.GaussianBlur(edges, (3, 3), 0)

    combined = cv2.addWeighted(gray, 0.7, edges, 0.3, 0)

    return image, combined

def extract_lbp(gray):
    # lbp = local_binary_pattern(gray, P=8, R=1)
    lbp = local_binary_pattern(gray, P=8, R=1, method='uniform')
    # hist, _ = np.histogram(lbp.ravel(), bins=64, range=(0, 256))
    hist, _ = np.histogram(lbp.ravel(), bins=60, range=(0, 60))
    hist = hist.astype("float")
    hist /= hist.sum()
    return hist

def extract_glcm(gray):
    a_gray = gray.astype(np.uint8)
    glcm = graycomatrix(gray, distances=[1], angles=[0], levels=256, symmetric=False, normed=True)
    features = [
        graycoprops(glcm, 'contrast')[0, 0],
        graycoprops(glcm, 'dissimilarity')[0, 0],
        graycoprops(glcm, 'homogeneity')[0, 0],
        graycoprops(glcm, 'energy')[0, 0],
        graycoprops(glcm, 'correlation')[0, 0]
    ]
    return np.array(features)

def extract_hog(gray):
    resized = cv2.resize(gray, (128, 128))
    features = hog(resized,
                   orientations=8,
                   pixels_per_cell=(16, 16),
                   cells_per_block=(1, 1),
                   visualize=False,
                   channel_axis=None)
    return features

def extract_laws(gray):
    (rows, cols) = gray.shape[:2]
    smooth_kernel = (1/25)*np.ones((5,5))
    gray_smooth = sg.convolve(gray, smooth_kernel,"same")
    gray_processed = np.abs(gray - gray_smooth)
    
    filter_vectors = np.array([[ 1,  4,  6,  4, 1],
                               [-1, -2,  0,  2, 1],
                               [-1,  0,  2,  0, 1],
                               [ 1, -4,  6, -4, 1]])

    filters = [np.matmul(fv1.reshape(5, 1), fv2.reshape(1, 5))
               for fv1 in filter_vectors for fv2 in filter_vectors]

    conv_maps = np.zeros((rows, cols, 16))
    for i in range(len(filters)):
        conv_maps[:, :, i] = sg.convolve(gray_processed, filters[i], 'same')

    texture_maps = [
        (conv_maps[:, :, 1]+conv_maps[:, :, 4])//2,
        (conv_maps[:, :, 2]+conv_maps[:, :, 8])//2,
        (conv_maps[:, :, 3]+conv_maps[:, :, 12])//2,
        (conv_maps[:, :, 7]+conv_maps[:, :, 13])//2,
        (conv_maps[:, :, 6]+conv_maps[:, :, 9])//2,
        (conv_maps[:, :, 11]+conv_maps[:, :, 14])//2,
        conv_maps[:, :, 10],
        conv_maps[:, :, 5],
        conv_maps[:, :, 15]
    ]
    norm_map = conv_maps[:, :, 0]
    TEM = [np.abs(tm).sum() / np.abs(norm_map).sum() for tm in texture_maps]
    TEM = np.array(TEM)
    TEM = TEM / np.linalg.norm(TEM)
    return TEM

# %% [markdown]
# ### process dataset

# %%
def process_dataset(dataset_path, method):
    features = []
    labels = []

    class_dirs = sorted([d for d in os.listdir(dataset_path) if os.path.isdir(os.path.join(dataset_path, d))])
    
    for cls in class_dirs:
        class_path = os.path.join(dataset_path, cls)
        image_files = sorted([f for f in os.listdir(class_path) if f.endswith('.png')])
        
        for img_file in tqdm(image_files, desc=f"{cls:12s} - {method.upper()}"):
            img_path = os.path.join(class_path, img_file)
            image, gray = preprocess_image(img_path)

            if method == 'lbp':
                feature = extract_lbp(gray)
            elif method == 'glcm':
                feature = extract_glcm(gray)
            elif method == 'hog':
                feature = extract_hog(gray)
            elif method == 'laws':
                feature = extract_laws(gray)
            else:
                continue

            features.append(feature)
            labels.append(cls)

    return np.array(features), np.array(labels)

# %% [markdown]
# ## Prepare labeled data

# %%
from sklearn.decomposition import PCA

dataset_path = "./recaptcha-dataset/Large"
methods = ["lbp", "glcm", "hog", "laws"]

loaded = {}

for method in methods:
    features, labels = process_dataset(dataset_path, method)
    loaded[method] = {
        'features': features,
        'labels': labels
    }

ref_method = methods[0]
assert all((loaded[m]['labels'] == loaded[ref_method]['labels']).all() for m in methods), "Label mismatch"

X_raw = np.concatenate([loaded[m]['features'] for m in methods], axis=1)
y = loaded[ref_method]['labels']

pca = PCA(n_components=100)
X = pca.fit_transform(X_raw)
# Out:
# Bicycle      - LBP: 100%|██████████| 800/800 [00:02<00:00, 310.86it/s]
# Bridge       - LBP: 100%|██████████| 553/553 [00:02<00:00, 269.42it/s]
# Bus          - LBP: 100%|██████████| 1229/1229 [00:03<00:00, 335.85it/s]
# Car          - LBP: 100%|██████████| 3578/3578 [00:11<00:00, 318.76it/s]
# Chimney      - LBP: 100%|██████████| 56/56 [00:00<00:00, 290.43it/s]
# Crosswalk    - LBP: 100%|██████████| 1260/1260 [00:04<00:00, 286.11it/s]
# Hydrant      - LBP: 100%|██████████| 972/972 [00:02<00:00, 337.25it/s]
# Motorcycle   - LBP: 100%|██████████| 101/101 [00:00<00:00, 304.69it/s]
# Palm         - LBP: 100%|██████████| 932/932 [00:02<00:00, 341.44it/s]
# Traffic Light - LBP: 100%|██████████| 811/811 [00:02<00:00, 298.86it/s]
# Bicycle      - GLCM: 100%|██████████| 800/800 [00:02<00:00, 331.23it/s]
# Bridge       - GLCM: 100%|██████████| 553/553 [00:02<00:00, 258.26it/s]
# Bus          - GLCM: 100%|██████████| 1229/1229 [00:04<00:00, 296.06it/s]
# Car          - GLCM: 100%|██████████| 3578/3578 [00:11<00:00, 305.24it/s]
# Chimney      - GLCM: 100%|██████████| 56/56 [00:00<00:00, 289.92it/s]
# Crosswalk    - GLCM: 100%|██████████| 1260/1260 [00:04<00:00, 305.11it/s]
# Hydrant      - GLCM: 100%|██████████| 972/972 [00:03<00:00, 310.96it/s]
# Motorcycle   - GLCM: 100%|██████████| 101/101 [00:00<00:00, 320.92it/s]
# Palm         - GLCM: 100%|██████████| 932/932 [00:03<00:00, 310.24it/s]
# Traffic Light - GLCM: 100%|██████████| 811/811 [00:02<00:00, 308.02it/s]
# Bicycle      - HOG: 100%|██████████| 800/800 [00:03<00:00, 260.54it/s]
# Bridge       - HOG: 100%|██████████| 553/553 [00:02<00:00, 273.06it/s]
# Bus          - HOG: 100%|██████████| 1229/1229 [00:04<00:00, 287.25it/s]
# Car          - HOG: 100%|██████████| 3578/3578 [00:12<00:00, 296.93it/s]
# Chimney      - HOG: 100%|██████████| 56/56 [00:00<00:00, 311.39it/s]
# Crosswalk    - HOG: 100%|██████████| 1260/1260 [00:04<00:00, 295.25it/s]
# Hydrant      - HOG: 100%|██████████| 972/972 [00:03<00:00, 289.71it/s]
# Motorcycle   - HOG: 100%|██████████| 101/101 [00:00<00:00, 306.38it/s]
# Palm         - HOG: 100%|██████████| 932/932 [00:03<00:00, 292.71it/s]
# Traffic Light - HOG: 100%|██████████| 811/811 [00:03<00:00, 262.02it/s]
# Bicycle      - LAWS: 100%|██████████| 800/800 [00:17<00:00, 46.05it/s]
# Bridge       - LAWS: 100%|██████████| 553/553 [00:18<00:00, 29.88it/s]
# Bus          - LAWS: 100%|██████████| 1229/1229 [00:26<00:00, 47.20it/s]
# Car          - LAWS: 100%|██████████| 3578/3578 [01:05<00:00, 54.36it/s]
# Chimney      - LAWS: 100%|██████████| 56/56 [00:01<00:00, 31.23it/s]
# Crosswalk    - LAWS: 100%|██████████| 1260/1260 [00:23<00:00, 53.99it/s]
# Hydrant      - LAWS: 100%|██████████| 972/972 [00:14<00:00, 68.54it/s]
# Motorcycle   - LAWS: 100%|██████████| 101/101 [00:01<00:00, 71.80it/s]
# Palm         - LAWS: 100%|██████████| 932/932 [00:13<00:00, 70.86it/s]
# Traffic Light - LAWS: 100%|██████████| 811/811 [00:13<00:00, 58.51it/s]

# %% [markdown]
# ### feature selection

# %%
def load_and_concat_features(method_list):
    feature_list = []
    labels = None
    for method in method_list:
        data = loaded[method]
        feature_list.append(data['features'])
        if labels is None:
            labels = data['labels']
    X_concat = np.concatenate(feature_list, axis=1)
    return X_concat, labels

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, f1_score


def evaluate_knn(X, y, k=3, folds=5):
    skf = StratifiedKFold(n_splits=folds, shuffle=True, random_state=42)
    acc_scores = []
    f1_scores = []

    for train_idx, test_idx in skf.split(X, y):
        X_train, X_test = X[train_idx], X[test_idx]
        y_train, y_test = y[train_idx], y[test_idx]

        clf = KNeighborsClassifier(n_neighbors=k)
        clf.fit(X_train, y_train)
        y_pred = clf.predict(X_test)

        acc_scores.append(accuracy_score(y_test, y_pred))
        f1_scores.append(f1_score(y_test, y_pred, average='macro'))

    return np.mean(acc_scores), np.mean(f1_scores)

# %%
from itertools import combinations

results = []
for r in range(1, len(methods)+1):
    for combo in combinations(methods, r):
        try:
            X, y = load_and_concat_features(combo)
            acc, f1 = evaluate_knn(X, y, k=3)
            results.append((combo, acc, f1))
            print(f"{combo} → Acc: {acc:.4f}, Macro-F1: {f1:.4f}")
        except Exception as e:
            print(f"{combo} 조합에서 오류 발생: {e}")

# 최고 성능 조합 출력
if results:
    best = max(results, key=lambda x: x[2])
    print("\nBest combination:", best[0])
    print(f"   Accuracy: {best[1]:.4f}, Macro-F1: {best[2]:.4f}")
else:
    print("유효한 feature 조합 결과 없음")
# Out:
# ('lbp',) → Acc: 0.3167, Macro-F1: 0.2039
# ('glcm',) → Acc: 0.2484, Macro-F1: 0.1363
# ('hog',) → Acc: 0.3117, Macro-F1: 0.1924
# ('laws',) → Acc: 0.2858, Macro-F1: 0.1747
# ('lbp', 'glcm') → Acc: 0.2495, Macro-F1: 0.1368
# ('lbp', 'hog') → Acc: 0.3130, Macro-F1: 0.1932
# ('lbp', 'laws') → Acc: 0.3495, Macro-F1: 0.2292
# ('glcm', 'hog') → Acc: 0.2935, Macro-F1: 0.1686
# ('glcm', 'laws') → Acc: 0.2493, Macro-F1: 0.1366
# ('hog', 'laws') → Acc: 0.3130, Macro-F1: 0.1938
# ('lbp', 'glcm', 'hog') → Acc: 0.2932, Macro-F1: 0.1683
# ('lbp', 'glcm', 'laws') → Acc: 0.2503, Macro-F1: 0.1368
# ('lbp', 'hog', 'laws') → Acc: 0.3149, Macro-F1: 0.1946
# ('glcm', 'hog', 'laws') → Acc: 0.2934, Macro-F1: 0.1685
# ('lbp', 'glcm', 'hog', 'laws') → Acc: 0.2936, Macro-F1: 0.1686
#
# Best combination: ('lbp', 'laws')
#    Accuracy: 0.3495, Macro-F1: 0.2292

# %% [markdown]
# ### Feature Vector Extraction

# %%
import os
import numpy as np


X_lbp = loaded['lbp']['features']
X_laws = loaded['laws']['features']
y_lbp = loaded['lbp']['labels']
y_laws = loaded['laws']['labels']

# 라벨 검증
assert np.array_equal(y_lbp, y_laws), "라벨이 일치하지 않습니다."

# feature vector combination
X_combined = np.concatenate([X_lbp, X_laws], axis=1)
y_combined = y_lbp

# 저장
os.makedirs("./prepared_feature", exist_ok=True)
np.save('./prepared_feature/X_train_lbp_laws_a3.npy', X_combined)
np.save('./prepared_feature/y_train_lbp_laws_a3.npy', y_combined)

print("Feature vector saved.")
print("X shape:", X_combined.shape)
print("y shape:", y_combined.shape)
# Out:
# Feature vector saved.
# X shape: (10292, 69)
# y shape: (10292,)

# %% [markdown]
# ## Prepare test data

# %%
# !git clone https://github.com/hbcbh1999/recaptcha-dataset.git

# %% [markdown]
# ### Preprocessing

# %%
image_dir = "./testset"
image_list = []

for fname in sorted(os.listdir(image_dir)):
    if fname.endswith(".png"):
        img_path = os.path.join(image_dir, fname)
        image = cv2.imread(img_path)

        if image is None:
            print(f"이미지 로딩 실패: {img_path}")
            continue 
        
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        gray = cv2.equalizeHist(gray)

        gray = cv2.medianBlur(gray, 3)

        edges = cv2.Canny(gray, 100, 200)

        combined = cv2.addWeighted(gray, 0.7, edges, 0.3, 0)

        image_list.append((fname, combined))

# %% [markdown]
# ## Feature extraction

# %%
def norm_hist(hist):
    # Normalize the histogram
    hist = hist.astype('float')
    hist /= hist.sum()
    return hist

# %% [markdown]
# ### LBP

# %%
lbp_features = []

# LBP
for fname, gray in image_list:
    lbp = local_binary_pattern(gray, P=8, R=1, method='uniform')

    hist_lbp, bin_lbp = np.histogram(lbp.ravel(), bins=60, range=(0, 60))
    hist_lbp = norm_hist(hist_lbp)    # 64-d
    lbp_features.append((fname, hist_lbp))

# %% [markdown]
# ### Law's texture

# %%
# Law's texture
def laws_texture(gray):
    (rows, cols) = gray.shape[:2]

    smooth_kernel = (1/25)*np.ones((5,5))
    gray_smooth = sg.convolve(gray, smooth_kernel,"same")
    gray_processed = np.abs(gray - gray_smooth)

    filter_vectors = np.array([[ 1,  4,  6,  4, 1],    # L5
                               [-1, -2,  0,  2, 1],    # E5
                               [-1,  0,  2,  0, 1],    # S5
                               [ 1, -4,  6, -4, 1]])   # R5

    # 0:L5L5, 1:L5E5, 2:L5S5, 3:L5R5,
    # 4:E5L5, 5:E5E5, 6:E5S5, 7:E5R5,
    # 8:S5L5, 9:S5E5, 10:S5S5, 11:S5R5,
    # 12:R5L5, 13:R5E5, 14:R5S5, 15:R5R5
    filters = list()
    for i in range(4):
        for j in range(4):
            filters.append(np.matmul(filter_vectors[i][:].reshape(5,1),
                                     filter_vectors[j][:].reshape(1,5)))

    conv_maps = np.zeros((rows, cols,16))
    for i in range(len(filters)):
        conv_maps[:, :, i] = sg.convolve(gray_processed,
                                         filters[i],'same')

    texture_maps = list()
    texture_maps.append((conv_maps[:, :, 1]+conv_maps[:, :, 4])//2)     # L5E5 / E5L5
    texture_maps.append((conv_maps[:, :, 2]+conv_maps[:, :, 8])//2)     # L5S5 / S5L5
    texture_maps.append((conv_maps[:, :, 3]+conv_maps[:, :, 12])//2)    # L5R5 / R5L5
    texture_maps.append((conv_maps[:, :, 7]+conv_maps[:, :, 13])//2)    # E5R5 / R5E5
    texture_maps.append((conv_maps[:, :, 6]+conv_maps[:, :, 9])//2)     # E5S5 / S5E5
    texture_maps.append((conv_maps[:, :, 11]+conv_maps[:, :, 14])//2)   # S5R5 / R5S5
    texture_maps.append(conv_maps[:, :, 10])                            # S5S5
    texture_maps.append(conv_maps[:, :, 5])                             # E5E5
    texture_maps.append(conv_maps[:, :, 15])                            # R5R5
    texture_maps.append(conv_maps[:, :, 0])                             # L5L5 (use to norm TEM)

    TEM = list()
    for i in range(9):
        TEM.append(np.abs(texture_maps[i]).sum() / np.abs(texture_maps[9]).sum())

    return TEM


laws_feature = []

for fname, gray in image_list:
    laws = laws_texture(gray)    # 9-d
    laws_feature.append((fname, np.array(laws)))

# %% [markdown]
# ### Load .npy Files

# %%
used_features = ['lbp', 'laws']
feature_dir = "./prepared_feature"

X_train_raw = np.load(os.path.join(feature_dir, "X_train_lbp_laws_a3.npy"))
y_train = np.load(os.path.join(feature_dir, "y_train_lbp_laws_a3.npy"))

pca = PCA(n_components=50)
X_train = pca.fit_transform(X_train_raw)

# %% [markdown]
# ### Combine feature vectors

# %%
test_features = []
test_filenames = []

for (fname1, lbp), (fname2, laws) in zip(lbp_features, laws_feature):
    assert fname1 == fname2, f"{fname1} != {fname2}"
    combined = np.concatenate([lbp, laws])
    test_features.append(combined)
    test_filenames.append(fname1)

X_test_raw = np.array(test_features)

X_test = pca.transform(X_test_raw)

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

classifier = KNeighborsClassifier(n_neighbors = 3)

classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# ### Task 1: Classification

# %%
predict_labels = classifier.predict(X_test)
print(predict_labels)    # array(100)
# Out:
# ['Crosswalk' 'Crosswalk' 'Crosswalk' 'Palm' 'Hydrant' 'Crosswalk' 'Palm'
#  'Crosswalk' 'Car' 'Car' 'Car' 'Palm' 'Crosswalk' 'Car' 'Crosswalk' 'Bus'
#  'Bus' 'Chimney' 'Crosswalk' 'Palm' 'Crosswalk' 'Bus' 'Crosswalk'
#  'Crosswalk' 'Palm' 'Crosswalk' 'Bus' 'Chimney' 'Crosswalk' 'Crosswalk'
#  'Chimney' 'Crosswalk' 'Chimney' 'Crosswalk' 'Car' 'Crosswalk' 'Crosswalk'
#  'Car' 'Bus' 'Crosswalk' 'Crosswalk' 'Traffic Light' 'Crosswalk'
#  'Crosswalk' 'Car' 'Bus' 'Car' 'Car' 'Palm' 'Car' 'Crosswalk' 'Bridge'
#  'Crosswalk' 'Crosswalk' 'Crosswalk' 'Bridge' 'Crosswalk' 'Chimney' 'Car'
#  'Crosswalk' 'Chimney' 'Crosswalk' 'Car' 'Palm' 'Bridge' 'Car' 'Crosswalk'
#  'Car' 'Crosswalk' 'Crosswalk' 'Crosswalk' 'Chimney' 'Car' 'Crosswalk'
#  'Hydrant' 'Crosswalk' 'Palm' 'Crosswalk' 'Crosswalk' 'Car' 'Palm'
#  'Traffic Light' 'Crosswalk' 'Car' 'Crosswalk' 'Bridge' 'Crosswalk'
#  'Crosswalk' 'Crosswalk' 'Bridge' 'Crosswalk' 'Crosswalk' 'Crosswalk'
#  'Crosswalk' 'Crosswalk' 'Palm' 'Crosswalk' 'Car' 'Palm' 'Crosswalk']

# %%
import csv

# with open('c1_t1_a1.csv','w') as file :
#     write = csv.writer(file)
#     for i, predict_label in enumerate(predict_labels):
#         write.writerow([f'query{i+1:03}.png', predict_label])

with open('c1_t1_a3.csv','w') as file :
    writer = csv.writer(file)
    for fname, pred in zip(test_filenames, predict_labels):
        writer.writerow([fname, pred])

# %% [markdown]
# ### Task 2: Retrieval

# %%
neigh_ind = classifier.kneighbors(X=X_test, n_neighbors=10, return_distance=False) # Top-10 results
neigh_labels = np.array(y_train)[neigh_ind]

# %%
print(neigh_labels)    # array(100x10)
# Out:
# [['Crosswalk' 'Hydrant' 'Crosswalk' 'Crosswalk' 'Crosswalk' 'Palm'
#   'Crosswalk' 'Crosswalk' 'Palm' 'Crosswalk']
#  ['Crosswalk' 'Crosswalk' 'Hydrant' 'Crosswalk' 'Crosswalk' 'Crosswalk'
#   'Crosswalk' 'Car' 'Car' 'Crosswalk']
#  ['Crosswalk' 'Crosswalk' 'Chimney' 'Crosswalk' 'Car' 'Crosswalk'
#   'Hydrant' 'Crosswalk' 'Crosswalk' 'Crosswalk']
#  ['Palm' 'Palm' 'Chimney' 'Car' 'Palm' 'Traffic Light' 'Palm'
#   'Traffic Light' 'Palm' 'Crosswalk']
#  ['Hydrant' 'Hydrant' 'Crosswalk' 'Car' 'Hydrant' 'Crosswalk'
#   'Motorcycle' 'Hydrant' 'Car' 'Hydrant']
#  ['Crosswalk' 'Palm' 'Crosswalk' 'Palm' 'Crosswalk' 'Crosswalk'
#   'Crosswalk' 'Traffic Light' 'Palm' 'Crosswalk']
#  ['Palm' 'Palm' 'Car' 'Traffic Light' 'Car' 'Hydrant' 'Car' 'Crosswalk'
#   'Car' 'Hydrant']
#  ['Crosswalk' 'Crosswalk' 'Palm' 'Crosswalk' 'Crosswalk' 'Car' 'Car'
#   'Crosswalk' 'Palm' 'Hydrant']
#  ['Car' 'Car' 'Palm' 'Car' 'Chimney' 'Hydrant' 'Car' 'Car' 'Crosswalk'
#   'Car']
#  ['Hydrant' 'Car' 'Crosswalk' 'Bridge' 'Crosswalk' 'Crosswalk' 'Chimney'
#   'Hydrant' 'Hydrant' 'Bicycle']
#  ['Car' 'Crosswalk' 'Palm' 'Crosswalk' 'Hydrant' 'Crosswalk' 'Bridge'
#   'Crosswalk' 'Crosswalk' 'Bus']
#  ['Palm' 'Palm' 'Bridge' 'Palm' 'Car' 'Palm' 'Crosswalk' 'Car' 'Car'
#   'Chimney']
#  ['Crosswalk' 'Crosswalk' 'Crosswalk' 'Bicycle' 'Hydrant' 'Palm' 'Palm'
#   'Crosswalk' 'Palm' 'Palm']
#  ['Traffic Light' 'Car' 'Palm' 'Bridge' 'Car' 'Chimney' 'Palm' 'Palm'
#   'Car' 'Car']
#  ['Crosswalk' 'Crosswalk' 'Crosswalk' 'Crosswalk' 'Crosswalk'
#   'Traffic Light' 'Hydrant' 'Chimney' 'Crosswalk' 'Crosswalk']
#  ['Palm' 'Bus' 'Bus' 'Car' 'Traffic Light' 'Car' 'Crosswalk' 'Bridge'
#   'Car' 'Palm']
#  ['Bus' 'Car' 'Crosswalk' 'Palm' 'Crosswalk' 'Palm' 'Palm' 'Car'
#   'Crosswalk' 'Bus']
#  ['Palm' 'Chimney' 'Traffic Light' 'Crosswalk' 'Palm' 'Crosswalk'
#   'Crosswalk' 'Hydrant' 'Car' 'Car']
#  ['Crosswalk' 'Crosswalk' 'Crosswalk' 'Hydrant' 'Crosswalk' 'Car'
#   'Crosswalk' 'Palm' 'Crosswalk' 'Palm']
#  ['Palm' 'Palm' 'Palm' 'Crosswalk' 'Car' 'Traffic Light' 'Car' 'Chimney'
#   'Palm' 'Palm']
#  ['Crosswalk' 'Crosswalk' 'Palm' 'Bus' 'Bus' 'Palm' 'Palm' 'Palm'
#   'Hydrant' 'Hydrant']
#  ['Car' 'Crosswalk' 'Bus' 'Crosswalk' 'Crosswalk' 'Car' 'Car' 'Car'
#   'Crosswalk' 'Car']
#  ['Crosswalk' 'Crosswalk' 'Crosswalk' 'Crosswalk' 'Crosswalk' 'Crosswalk'
#   'Crosswalk' 'Crosswalk' 'Crosswalk' 'Crosswalk']
#  ['Crosswalk' 'Hydrant' 'Palm' 'Hydrant' 'Palm' 'Bridge' 'Car' 'Bus'
#   'Bridge' 'Bicycle']
#  ['Traffic Light' 'Palm' 'Palm' 'Palm' 'Palm' 'Car' 'Motorcycle' 'Car'
#   'Palm' 'Car']
#  ['Crosswalk' 'Crosswalk' 'Bus' 'Bus' 'Car' 'Crosswalk' 'Crosswalk'
#   'Palm' 'Crosswalk' 'Crosswalk']
#  ['Bus' 'Palm' 'Bus' 'Bridge' 'Car' 'Car' 'Car' 'Car' 'Traffic Light'
#   'Palm']
#  ['Crosswalk' 'Chimney' 'Hydrant' 'Hydrant' 'Crosswalk' 'Crosswalk'
#   'Crosswalk' 'Chimney' 'Crosswalk' 'Bridge']
#  ['Crosswalk' 'Crosswalk' 'Chimney' 'Hydrant' 'Crosswalk' 'Crosswalk'
#   'Car' 'Crosswalk' 'Crosswalk' 'Crosswalk']
#  ['Car' 'Crosswalk' 'Crosswalk' 'Palm' 'Hydrant' 'Crosswalk' 'Car'
#   'Crosswalk' 'Hydrant' 'Crosswalk']
#  ['Crosswalk' 'Chimney' 'Hydrant' 'Bridge' 'Crosswalk' 'Car' 'Car'
#   'Crosswalk' 'Crosswalk' 'Crosswalk']
#  ['Crosswalk' 'Crosswalk' 'Crosswalk' 'Crosswalk' 'Crosswalk' 'Crosswalk'
#   'Crosswalk' 'Chimney' 'Crosswalk' 'Car']
#  ['Chimney' 'Hydrant' 'Chimney' 'Crosswalk' 'Crosswalk' 'Crosswalk'
#   'Crosswalk' 'Crosswalk' 'Crosswalk' 'Bridge']
#  ['Crosswalk' 'Crosswalk' 'Crosswalk' 'Palm' 'Palm' 'Palm' 'Crosswalk'
#   'Crosswalk' 'Motorcycle' 'Palm']
#  ['Chimney' 'Crosswalk' 'Car' 'Crosswalk' 'Crosswalk' 'Crosswalk'
#   'Crosswalk' 'Hydrant' 'Crosswalk' 'Crosswalk']
#  ['Crosswalk' 'Crosswalk' 'Crosswalk' 'Bus' 'Bus' 'Hydrant' 'Crosswalk'
#   'Chimney' 'Car' 'Crosswalk']
#  ['Crosswalk' 'Palm' 'Crosswalk' 'Crosswalk' 'Crosswalk' 'Crosswalk'
#   'Crosswalk' 'Crosswalk' 'Motorcycle' 'Crosswalk']
#  ['Traffic Light' 'Car' 'Hydrant' 'Car' 'Crosswalk' 'Palm' 'Bus'
#   'Bicycle' 'Crosswalk' 'Car']
#  ['Crosswalk' 'Car' 'Bus' 'Bus' 'Crosswalk' 'Crosswalk' 'Bus' 'Palm'
#   'Bus' 'Bus']
#  ['Crosswalk' 'Crosswalk' 'Crosswalk' 'Crosswalk' 'Crosswalk' 'Crosswalk'
#   'Crosswalk' 'Chimney' 'Crosswalk' 'Crosswalk']
#  ['Palm' 'Crosswalk' 'Crosswalk' 'Crosswalk' 'Palm' 'Crosswalk'
#   'Crosswalk' 'Bridge' 'Crosswalk' 'Crosswalk']
#  ['Traffic Light' 'Crosswalk' 'Traffic Light' 'Palm' 'Car' 'Palm'
#   'Crosswalk' 'Palm' 'Hydrant' 'Crosswalk']
#  ['Crosswalk' 'Crosswalk' 'Crosswalk' 'Crosswalk' 'Chimney' 'Crosswalk'
#   'Hydrant' 'Crosswalk' 'Crosswalk' 'Car']
#  ['Crosswalk' 'Crosswalk' 'Crosswalk' 'Hydrant' 'Chimney' 'Crosswalk'
#   'Crosswalk' 'Car' 'Bus' 'Bus']
#  ['Crosswalk' 'Car' 'Motorcycle' 'Crosswalk' 'Crosswalk' 'Crosswalk'
#   'Crosswalk' 'Car' 'Motorcycle' 'Car']
#  ['Crosswalk' 'Bus' 'Bus' 'Car' 'Bus' 'Palm' 'Bus' 'Bus' 'Palm'
#   'Crosswalk']
#  ['Crosswalk' 'Car' 'Chimney' 'Crosswalk' 'Hydrant' 'Crosswalk'
#   'Crosswalk' 'Hydrant' 'Crosswalk' 'Crosswalk']
#  ['Car' 'Car' 'Hydrant' 'Chimney' 'Palm' 'Car' 'Crosswalk' 'Crosswalk'
#   'Bicycle' 'Car']
#  ['Palm' 'Traffic Light' 'Palm' 'Car' 'Traffic Light' 'Palm'
#   'Traffic Light' 'Traffic Light' 'Car' 'Bridge']
#  ['Car' 'Traffic Light' 'Palm' 'Bridge' 'Traffic Light' 'Car' 'Car'
#   'Bridge' 'Palm' 'Traffic Light']
#  ['Crosswalk' 'Palm' 'Crosswalk' 'Bus' 'Bridge' 'Bicycle' 'Crosswalk'
#   'Traffic Light' 'Car' 'Car']
#  ['Crosswalk' 'Palm' 'Bridge' 'Crosswalk' 'Hydrant' 'Palm' 'Chimney'
#   'Car' 'Crosswalk' 'Car']
#  ['Hydrant' 'Crosswalk' 'Crosswalk' 'Crosswalk' 'Crosswalk' 'Car'
#   'Crosswalk' 'Crosswalk' 'Palm' 'Crosswalk']
#  ['Crosswalk' 'Palm' 'Crosswalk' 'Crosswalk' 'Hydrant' 'Crosswalk' 'Car'
#   'Car' 'Traffic Light' 'Palm']
#  ['Crosswalk' 'Crosswalk' 'Crosswalk' 'Chimney' 'Hydrant' 'Crosswalk'
#   'Crosswalk' 'Crosswalk' 'Crosswalk' 'Car']
#  ['Bus' 'Bridge' 'Crosswalk' 'Car' 'Palm' 'Palm' 'Crosswalk'
#   'Traffic Light' 'Palm' 'Car']
#  ['Crosswalk' 'Crosswalk' 'Palm' 'Car' 'Crosswalk' 'Crosswalk' 'Car'
#   'Crosswalk' 'Crosswalk' 'Crosswalk']
#  ['Palm' 'Traffic Light' 'Chimney' 'Palm' 'Crosswalk' 'Car'
#   'Traffic Light' 'Palm' 'Car' 'Car']
#  ['Car' 'Hydrant' 'Crosswalk' 'Crosswalk' 'Hydrant' 'Car' 'Crosswalk'
#   'Crosswalk' 'Bridge' 'Crosswalk']
#  ['Traffic Light' 'Crosswalk' 'Palm' 'Car' 'Car' 'Car' 'Car' 'Palm'
#   'Palm' 'Chimney']
#  ['Palm' 'Traffic Light' 'Chimney' 'Traffic Light' 'Palm' 'Palm' 'Palm'
#   'Palm' 'Car' 'Traffic Light']
#  ['Crosswalk' 'Crosswalk' 'Hydrant' 'Chimney' 'Crosswalk' 'Crosswalk'
#   'Crosswalk' 'Crosswalk' 'Crosswalk' 'Crosswalk']
#  ['Palm' 'Crosswalk' 'Car' 'Crosswalk' 'Crosswalk' 'Palm' 'Crosswalk'
#   'Bicycle' 'Car' 'Car']
#  ['Palm' 'Traffic Light' 'Palm' 'Car' 'Palm' 'Car' 'Chimney'
#   'Traffic Light' 'Palm' 'Car']
#  ['Bridge' 'Hydrant' 'Crosswalk' 'Palm' 'Crosswalk' 'Crosswalk' 'Car'
#   'Hydrant' 'Bicycle' 'Hydrant']
#  ['Car' 'Palm' 'Car' 'Car' 'Chimney' 'Traffic Light' 'Hydrant' 'Car'
#   'Car' 'Car']
#  ['Crosswalk' 'Crosswalk' 'Crosswalk' 'Palm' 'Motorcycle' 'Crosswalk'
#   'Crosswalk' 'Palm' 'Crosswalk' 'Car']
#  ['Hydrant' 'Car' 'Car' 'Car' 'Crosswalk' 'Crosswalk' 'Car' 'Crosswalk'
#   'Crosswalk' 'Crosswalk']
#  ['Traffic Light' 'Crosswalk' 'Palm' 'Car' 'Car' 'Traffic Light' 'Palm'
#   'Car' 'Crosswalk' 'Traffic Light']
#  ['Crosswalk' 'Crosswalk' 'Crosswalk' 'Crosswalk' 'Crosswalk' 'Crosswalk'
#   'Crosswalk' 'Crosswalk' 'Traffic Light' 'Crosswalk']
#  ['Crosswalk' 'Crosswalk' 'Motorcycle' 'Crosswalk' 'Crosswalk' 'Palm'
#   'Crosswalk' 'Car' 'Bus' 'Palm']
#  ['Chimney' 'Crosswalk' 'Hydrant' 'Car' 'Crosswalk' 'Crosswalk'
#   'Crosswalk' 'Crosswalk' 'Crosswalk' 'Crosswalk']
#  ['Crosswalk' 'Car' 'Hydrant' 'Chimney' 'Palm' 'Palm' 'Crosswalk'
#   'Crosswalk' 'Crosswalk' 'Crosswalk']
#  ['Crosswalk' 'Crosswalk' 'Car' 'Crosswalk' 'Crosswalk' 'Crosswalk'
#   'Hydrant' 'Car' 'Bicycle' 'Hydrant']
#  ['Hydrant' 'Traffic Light' 'Palm' 'Palm' 'Palm' 'Car' 'Car'
#   'Traffic Light' 'Palm' 'Traffic Light']
#  ['Crosswalk' 'Crosswalk' 'Crosswalk' 'Crosswalk' 'Car' 'Crosswalk'
#   'Crosswalk' 'Crosswalk' 'Car' 'Crosswalk']
#  ['Palm' 'Car' 'Palm' 'Crosswalk' 'Crosswalk' 'Hydrant' 'Crosswalk'
#   'Crosswalk' 'Crosswalk' 'Bicycle']
#  ['Crosswalk' 'Crosswalk' 'Chimney' 'Crosswalk' 'Crosswalk' 'Crosswalk'
#   'Crosswalk' 'Hydrant' 'Crosswalk' 'Crosswalk']
#  ['Car' 'Crosswalk' 'Crosswalk' 'Crosswalk' 'Crosswalk' 'Car' 'Crosswalk'
#   'Crosswalk' 'Palm' 'Crosswalk']
#  ['Crosswalk' 'Car' 'Palm' 'Palm' 'Palm' 'Palm' 'Palm' 'Car' 'Bicycle'
#   'Car']
#  ['Palm' 'Palm' 'Traffic Light' 'Traffic Light' 'Car' 'Traffic Light'
#   'Bridge' 'Chimney' 'Car' 'Palm']
#  ['Palm' 'Traffic Light' 'Traffic Light' 'Traffic Light' 'Traffic Light'
#   'Palm' 'Palm' 'Chimney' 'Traffic Light' 'Palm']
#  ['Car' 'Crosswalk' 'Crosswalk' 'Car' 'Palm' 'Car' 'Traffic Light' 'Car'
#   'Motorcycle' 'Crosswalk']
#  ['Car' 'Crosswalk' 'Hydrant' 'Crosswalk' 'Crosswalk' 'Hydrant' 'Chimney'
#   'Crosswalk' 'Bridge' 'Bridge']
#  ['Crosswalk' 'Crosswalk' 'Crosswalk' 'Bus' 'Bus' 'Hydrant' 'Car'
#   'Crosswalk' 'Chimney' 'Bus']
#  ['Bridge' 'Palm' 'Crosswalk' 'Crosswalk' 'Car' 'Chimney' 'Bus'
#   'Crosswalk' 'Car' 'Crosswalk']
#  ['Crosswalk' 'Crosswalk' 'Crosswalk' 'Bus' 'Car' 'Car' 'Crosswalk'
#   'Motorcycle' 'Bus' 'Crosswalk']
#  ['Crosswalk' 'Car' 'Crosswalk' 'Bus' 'Bus' 'Crosswalk' 'Crosswalk'
#   'Crosswalk' 'Bus' 'Bus']
#  ['Crosswalk' 'Bus' 'Crosswalk' 'Bicycle' 'Palm' 'Crosswalk' 'Crosswalk'
#   'Car' 'Hydrant' 'Car']
#  ['Palm' 'Bridge' 'Car' 'Traffic Light' 'Bus' 'Car' 'Car' 'Traffic Light'
#   'Car' 'Bridge']
#  ['Crosswalk' 'Hydrant' 'Crosswalk' 'Car' 'Crosswalk' 'Crosswalk'
#   'Crosswalk' 'Crosswalk' 'Crosswalk' 'Crosswalk']
#  ['Palm' 'Crosswalk' 'Crosswalk' 'Crosswalk' 'Crosswalk' 'Car'
#   'Crosswalk' 'Crosswalk' 'Crosswalk' 'Crosswalk']
#  ['Chimney' 'Crosswalk' 'Crosswalk' 'Hydrant' 'Crosswalk' 'Hydrant'
#   'Crosswalk' 'Crosswalk' 'Crosswalk' 'Car']
#  ['Crosswalk' 'Crosswalk' 'Crosswalk' 'Chimney' 'Crosswalk' 'Hydrant'
#   'Crosswalk' 'Crosswalk' 'Bridge' 'Crosswalk']
#  ['Crosswalk' 'Crosswalk' 'Crosswalk' 'Hydrant' 'Crosswalk' 'Bus' 'Bus'
#   'Chimney' 'Crosswalk' 'Crosswalk']
#  ['Palm' 'Traffic Light' 'Palm' 'Chimney' 'Palm' 'Traffic Light' 'Palm'
#   'Palm' 'Car' 'Palm']
#  ['Crosswalk' 'Crosswalk' 'Crosswalk' 'Crosswalk' 'Crosswalk' 'Hydrant'
#   'Crosswalk' 'Car' 'Chimney' 'Crosswalk']
#  ['Car' 'Motorcycle' 'Crosswalk' 'Motorcycle' 'Crosswalk' 'Bus'
#   'Crosswalk' 'Car' 'Palm' 'Car']
#  ['Palm' 'Car' 'Palm' 'Palm' 'Crosswalk' 'Palm' 'Traffic Light' 'Palm'
#   'Traffic Light' 'Bus']
#  ['Crosswalk' 'Crosswalk' 'Crosswalk' 'Palm' 'Traffic Light' 'Hydrant'
#   'Car' 'Crosswalk' 'Palm' 'Bicycle']]

# %%
import csv

with open('c1_t2_a3.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    for fname, neigh_label in zip(test_filenames, neigh_labels):
        writer.writerow([fname] + list(neigh_label))
